# %%
import math
import pandas as pd
import numpy as np
import igraph
import itertools
import matplotlib.pyplot as plt
from notears import linear
from notears import utils
# %matplotlib inline

tol = 0.00001

# %%
class dag():
    
    def __init__(self, m):
        '''
        m is a pandas DataFrame conaining an adjacency matrix
        '''
        self.m = m
        self.nodes = self.m.columns.values
        self.lags = np.array([n for n in self.nodes if '_1' in n])
        if not all(self.m.columns.values == self.m.index.values):
            raise ValueError('Invalid adjacency matrix (columns and rows are not the same)')
        self.directed = self.directed()

            
    def parents(self, n):
        '''
        n is a node in the graph
        '''
        if n not in self.nodes:
            raise ValueError('n is not in graph')
        return self.m.loc[self.m.loc[:,n] != 0, n].index.values
    
    
    def children(self, n):
        '''
        n is a node in the graph
        '''
        if n not in self.nodes:
            raise ValueError('n is not in graph')
        return self.m.loc[:,self.m.loc[n,:] != 0].columns.values
    
    
    def directed(self):
        directed = True
        for n in self.nodes:
            if len(set(self.parents(n)).intersection(set(self.children(n)))) != 0:
                directed = False
        return directed
        
    
    def depth(self, n):
        '''
        n is a node in the graph
        return the length of the shortest path to a root node
        '''
        if not self.directed:
            raise ValueError('Cannot compute depth, graph is undirected')
        if len(self.parents(n)) == 0:
            return 0
        else:
            return 1 + min([self.depth(p) for p in self.parents(n)])
    
    
    def root_nodes(self):
        return np.array([n for n in self.nodes if len(self.parents(n)) == 0])
        
        
    def isolated_nodes(self):
        return np.array([n for n in d.nodes if (len(d.parents(n)) == 0) & (len(d.children(n)) == 0)])
    
    
    def connected_roots(self):
        return np.array([n for n in d.nodes if (len(d.parents(n)) == 0) & (len(d.children(n)) > 0)])
    
    
    def structure(self):
        M = self.m.copy()
        M[M != 0] = 1
        return M
    
    
    def shd(self, d):
        try:
            return utils.count_accuracy(d.structure().values, self.structure().values)['shd']
        except ValueError as e:
            # Graph is not directed
            return None
    
    
    def calculate_irf(self, x_0, T=250):
        out = pd.DataFrame([x_0], columns=self.nodes)
        for t in range(T):
            d = 0
            new_row = pd.DataFrame([], columns=self.nodes)
            while True:
                layer = [n for n in self.nodes if self.depth(n) == d]
                if len(layer) == 0:
                    out = pd.concat([out, new_row], axis=0)
                    break
                for n in layer:
                    if n in self.lags:
                        new_row.loc[0,n] = out.iloc[-1,:][n.rstrip('_1')]
                    elif d == 0:
                        new_row.loc[0,n] = 0
                    else:
                        new_row.loc[0,n] = np.dot(self.m.loc[:,n], new_row.iloc[0,:].fillna(0))
                d += 1   
        out.loc[:,'t'] = range(T+1)
        out.set_index('t', inplace=True)
        out.drop(self.lags, axis=1, inplace=True)
        return out
    
    
    def plot_irf(self, irf, layout=None):
        if layout is None:
            side = math.ceil(math.sqrt(len(irf.columns)))
            layout = (side, side)
        axes = irf.plot(subplots=True, layout=layout, color="black", legend=False)
        for ax, name in zip(axes.flatten(), [x for x in self.nodes if x not in self.lags]):
            ax.axhline(y=0, color="red")
            ax.set_title(name)
        return plt
    
    
    def plot_structure(self):
        M = self.m.values
        g = igraph.Graph.Adjacency((M != 0.0).tolist())
        g.es['weight'] = M[M.nonzero()]
        g.vs['label'] = self.nodes
        g.vs['color'] = 'white'
        g.vs['size'] = 45
        return g

# %%
data = pd.read_csv('../data/rbc_100k.csv')
data = data.drop(list(['eps_z', 'eps_g']), axis=1)
data.columns = [col.replace(" ", "") for col in data.columns]
data = data.iloc[:,1:]
# data = data.loc[:,np.array(['y', 'z'])]

data = data.apply(lambda x: x - x.mean())

shift_vars = data.columns.values
shift = data.loc[:,shift_vars].shift()
shift.columns = [str(col) + '_1' for col in shift.columns]
data = pd.concat([data, shift], axis=1)
data = data.iloc[1:,:]

data_array = data.values

# %%
bl_children = np.where(np.isin(data.columns.values, shift.columns.values))[0]
bl_parents  = None # np.where(~np.isin(data.columns.values, shift.columns.values))[0]
d = data_array.shape[1]
# DAG
dag_bnds = [
        (0, 0)
        if i == j
        else (0, 0) 
        if bl_parents is not None and i in bl_parents
        else (0, 0) 
        if bl_children is not None and j in bl_children
        else (-1 + tol, 1 - tol) # Assume stationary solution
        for i in range(d)
        for j in range(d)
    ]

# %%
d = len(data.columns)
gt = pd.DataFrame(np.zeros((len(data.columns), len(data.columns))), columns=data.columns, index=data.columns)
for j in ['z', 'g', 'k_1']:
    h = gt.columns[0:np.int(d/2)]
    gt.loc[j,h] = 1
    
gt.loc['z_1', 'z'] = 1
gt.loc['g_1', 'g'] = 1

gt.loc['k_1', 'k_1'] = 0
gt.loc['z', 'z'] = 0
gt.loc['g', 'g'] = 0

gt.loc['g', 'z'] = 0
gt.loc['z', 'g'] = 0
gt.loc['k_1', 'z'] = 0
gt.loc['k_1', 'g'] = 0
gt.loc['g', 'k_1'] = 0
gt.loc['g', 'k_1'] = 0
gt.loc['z', 'k_1'] = 0
gt.loc['z', 'k_1'] = 0

gt = dag(gt)

# %%
def grid_search():
    results = pd.DataFrame(columns=['SHD', 'root_nodes', 'directed', 'dag', 'params'])
    lambda1s = np.linspace(1e1, 1e-50, 10) 
    w_thresholds = np.linspace(0, 0.99, 10)
    loss_types = ['l2', 'logistic', 'poisson']
    bndss = [dag_bnds]
    params = [lambda1s, w_thresholds, loss_types, bndss]
    grid = list(itertools.product(*params))
    gridsize = len(grid)
    
    i = 1
    for p in grid:
        W_est = linear.notears_linear(data_array, 
                                      lambda1=p[0], 
                                      w_threshold=p[1],
                                      loss_type=p[2], 
                                      bnds=p[3],
                                      max_iter=1000, 
                                      h_tol=1e-8, 
                                      rho_max=1e+20)
        d = dag(pd.DataFrame(W_est, index=data.columns.values, columns=data.columns.values))
        shd = d.shd(gt)
        root_nodes = d.root_nodes()
        directed = d.directed

        results = results.append({
            'SHD': shd,
            'root_nodes': root_nodes,
            'directed': directed,
            'dag': d,
            'params': {
                'lambda1': p[0],
                'w_threshold': p[1],
                'loss_type': p[2],
                'bnds': p[3]
            }
         }, ignore_index=True)
        print('Completed iteration {} of {} ({}%)\n SHD: {}'.format(i, gridsize, np.round(i/gridsize*100, 2), shd))
        i += 1
        
        
    print('FINISHED')
    return results

# %%
results = grid_search()
# Out:
# Completed iteration 1 of 300 (0.33%)
#  SHD: None
# Completed iteration 2 of 300 (0.67%)
#  SHD: None
# Completed iteration 3 of 300 (1.0%)
#  SHD: None
# Completed iteration 4 of 300 (1.33%)
#  SHD: 107
# Completed iteration 5 of 300 (1.67%)
#  SHD: 102
# Completed iteration 6 of 300 (2.0%)
#  SHD: 107
# Completed iteration 7 of 300 (2.33%)
#  SHD: 104
# Completed iteration 8 of 300 (2.67%)
#  SHD: 102
# Completed iteration 9 of 300 (3.0%)
#  SHD: 105
# Completed iteration 10 of 300 (3.33%)
#  SHD: 102
# Completed iteration 11 of 300 (3.67%)
#  SHD: 102
# Completed iteration 12 of 300 (4.0%)
#  SHD: 101
# Completed iteration 13 of 300 (4.33%)
#  SHD: 98
# Completed iteration 14 of 300 (4.67%)
#  SHD: 102
# Completed iteration 15 of 300 (5.0%)
#  SHD: 97
# Completed iteration 16 of 300 (5.33%)
#  SHD: 94
# Completed iteration 17 of 300 (5.67%)
#  SHD: 103
# Completed iteration 18 of 300 (6.0%)
#  SHD: 97
# Completed iteration 19 of 300 (6.33%)
#  SHD: 93
# Completed iteration 20 of 300 (6.67%)
#  SHD: 103
# Completed iteration 21 of 300 (7.0%)
#  SHD: 96
# Completed iteration 22 of 300 (7.33%)
#  SHD: 93
# Completed iteration 23 of 300 (7.67%)
#  SHD: 103
# Completed iteration 24 of 300 (8.0%)
#  SHD: 95
# Completed iteration 25 of 300 (8.33%)
#  SHD: 92
# Completed iteration 26 of 300 (8.67%)
#  SHD: 103
# Completed iteration 27 of 300 (9.0%)
#  SHD: 94
# Completed iteration 28 of 300 (9.33%)
#  SHD: 93
# Completed iteration 29 of 300 (9.67%)
#  SHD: 103
# Completed iteration 30 of 300 (10.0%)
#  SHD: 91
# Completed iteration 31 of 300 (10.33%)
#  SHD: None
# Completed iteration 32 of 300 (10.67%)
#  SHD: None
# Completed iteration 33 of 300 (11.0%)
#  SHD: None
# Completed iteration 34 of 300 (11.33%)
#  SHD: 105
# Completed iteration 35 of 300 (11.67%)
#  SHD: 102
# Completed iteration 36 of 300 (12.0%)
#  SHD: 106
# Completed iteration 37 of 300 (12.33%)
#  SHD: 102
# Completed iteration 38 of 300 (12.67%)
#  SHD: 103
# Completed iteration 39 of 300 (13.0%)
#  SHD: 105
# Completed iteration 40 of 300 (13.33%)
#  SHD: 98
# Completed iteration 41 of 300 (13.67%)
#  SHD: 103
# Completed iteration 42 of 300 (14.0%)
#  SHD: 102
# Completed iteration 43 of 300 (14.33%)
#  SHD: 97
# Completed iteration 44 of 300 (14.67%)
#  SHD: 103
# Completed iteration 45 of 300 (15.0%)
#  SHD: 98
# Completed iteration 46 of 300 (15.33%)
#  SHD: 97
# Completed iteration 47 of 300 (15.67%)
#  SHD: 103
# Completed iteration 48 of 300 (16.0%)
#  SHD: 97
# Completed iteration 49 of 300 (16.33%)
#  SHD: 95
# Completed iteration 50 of 300 (16.67%)
#  SHD: 103
# Completed iteration 51 of 300 (17.0%)
#  SHD: 96
# Completed iteration 52 of 300 (17.33%)
#  SHD: 95
# Completed iteration 53 of 300 (17.67%)
#  SHD: 103
# Completed iteration 54 of 300 (18.0%)
#  SHD: 96
# Completed iteration 55 of 300 (18.33%)
#  SHD: 94
# Completed iteration 56 of 300 (18.67%)
#  SHD: 103
# Completed iteration 57 of 300 (19.0%)
#  SHD: 94
# Completed iteration 58 of 300 (19.33%)
#  SHD: 96
# Completed iteration 59 of 300 (19.67%)
#  SHD: 103
# Completed iteration 60 of 300 (20.0%)
#  SHD: 90
# Completed iteration 61 of 300 (20.33%)
#  SHD: None
# Completed iteration 62 of 300 (20.67%)
#  SHD: None
# Completed iteration 63 of 300 (21.0%)
#  SHD: None
# Completed iteration 64 of 300 (21.33%)
#  SHD: 106
# Completed iteration 65 of 300 (21.67%)
#  SHD: 99
# Completed iteration 66 of 300 (22.0%)
#  SHD: 106
# Completed iteration 67 of 300 (22.33%)
#  SHD: 102
# Completed iteration 68 of 300 (22.67%)
#  SHD: 99
# Completed iteration 69 of 300 (23.0%)
#  SHD: 103
# Completed iteration 70 of 300 (23.33%)
#  SHD: 97
# Completed iteration 71 of 300 (23.67%)
#  SHD: 99
# Completed iteration 72 of 300 (24.0%)
#  SHD: 102
# Completed iteration 73 of 300 (24.33%)
#  SHD: 93
# Completed iteration 74 of 300 (24.67%)
#  SHD: 99
# Completed iteration 75 of 300 (25.0%)
#  SHD: 99
# Completed iteration 76 of 300 (25.33%)
#  SHD: 94
# Completed iteration 77 of 300 (25.67%)
#  SHD: 99
# Completed iteration 78 of 300 (26.0%)
#  SHD: 97
# Completed iteration 79 of 300 (26.33%)
#  SHD: 94
# Completed iteration 80 of 300 (26.67%)
#  SHD: 99
# Completed iteration 81 of 300 (27.0%)
#  SHD: 96
# Completed iteration 82 of 300 (27.33%)
#  SHD: 93
# Completed iteration 83 of 300 (27.67%)
#  SHD: 99
# Completed iteration 84 of 300 (28.0%)
#  SHD: 96
# Completed iteration 85 of 300 (28.33%)
#  SHD: 93
# Completed iteration 86 of 300 (28.67%)
#  SHD: 99
# Completed iteration 87 of 300 (29.0%)
#  SHD: 94
# Completed iteration 88 of 300 (29.33%)
#  SHD: 94
# Completed iteration 89 of 300 (29.67%)
#  SHD: 99
# Completed iteration 90 of 300 (30.0%)
#  SHD: 91
# Completed iteration 91 of 300 (30.33%)
#  SHD: None
# Completed iteration 92 of 300 (30.67%)
#  SHD: None
# Completed iteration 93 of 300 (31.0%)
#  SHD: None
# Completed iteration 94 of 300 (31.33%)
#  SHD: 103
# Completed iteration 95 of 300 (31.67%)
#  SHD: 99
# Completed iteration 96 of 300 (32.0%)
#  SHD: 106
# Completed iteration 97 of 300 (32.33%)
#  SHD: 99
# Completed iteration 98 of 300 (32.67%)
#  SHD: 100
# Completed iteration 99 of 300 (33.0%)
#  SHD: 101
# Completed iteration 100 of 300 (33.33%)
#  SHD: 94
# Completed iteration 101 of 300 (33.67%)
#  SHD: 100
# Completed iteration 102 of 300 (34.0%)
#  SHD: 101
# Completed iteration 103 of 300 (34.33%)
#  SHD: 94
# Completed iteration 104 of 300 (34.67%)
#  SHD: 100
# Completed iteration 105 of 300 (35.0%)
#  SHD: 100
# Completed iteration 106 of 300 (35.33%)
#  SHD: 95
# Completed iteration 107 of 300 (35.67%)
#  SHD: 100
# Completed iteration 108 of 300 (36.0%)
#  SHD: 97
# Completed iteration 109 of 300 (36.33%)
#  SHD: 95
# Completed iteration 110 of 300 (36.67%)
#  SHD: 100
# Completed iteration 111 of 300 (37.0%)
#  SHD: 97
# Completed iteration 112 of 300 (37.33%)
#  SHD: 95
# Completed iteration 113 of 300 (37.67%)
#  SHD: 100
# Completed iteration 114 of 300 (38.0%)
#  SHD: 94
# Completed iteration 115 of 300 (38.33%)
#  SHD: 94
# Completed iteration 116 of 300 (38.67%)
#  SHD: 100
# Completed iteration 117 of 300 (39.0%)
#  SHD: 94
# Completed iteration 118 of 300 (39.33%)
#  SHD: 94
# Completed iteration 119 of 300 (39.67%)
#  SHD: 100
# Completed iteration 120 of 300 (40.0%)
#  SHD: 90
# Completed iteration 121 of 300 (40.33%)
#  SHD: None
# Completed iteration 122 of 300 (40.67%)
#  SHD: None
# Completed iteration 123 of 300 (41.0%)
#  SHD: None
# Completed iteration 124 of 300 (41.33%)
#  SHD: 104
# Completed iteration 125 of 300 (41.67%)
#  SHD: 99
# Completed iteration 126 of 300 (42.0%)
#  SHD: 105
# Completed iteration 127 of 300 (42.33%)
#  SHD: 101
# Completed iteration 128 of 300 (42.67%)
#  SHD: 101
# Completed iteration 129 of 300 (43.0%)
#  SHD: 102
# Completed iteration 130 of 300 (43.33%)
#  SHD: 96
# Completed iteration 131 of 300 (43.67%)
#  SHD: 101
# Completed iteration 132 of 300 (44.0%)
#  SHD: 101
# Completed iteration 133 of 300 (44.33%)
#  SHD: 96
# Completed iteration 134 of 300 (44.67%)
#  SHD: 101
# Completed iteration 135 of 300 (45.0%)
#  SHD: 100
# Completed iteration 136 of 300 (45.33%)
#  SHD: 94
# Completed iteration 137 of 300 (45.67%)
#  SHD: 101
# Completed iteration 138 of 300 (46.0%)
#  SHD: 98
# Completed iteration 139 of 300 (46.33%)
#  SHD: 95
# Completed iteration 140 of 300 (46.67%)
#  SHD: 101
# Completed iteration 141 of 300 (47.0%)
#  SHD: 97
# Completed iteration 142 of 300 (47.33%)
#  SHD: 95
# Completed iteration 143 of 300 (47.67%)
#  SHD: 101
# Completed iteration 144 of 300 (48.0%)
#  SHD: 95
# Completed iteration 145 of 300 (48.33%)
#  SHD: 95
# Completed iteration 146 of 300 (48.67%)
#  SHD: 101
# Completed iteration 147 of 300 (49.0%)
#  SHD: 94
# Completed iteration 148 of 300 (49.33%)
#  SHD: 96
# Completed iteration 149 of 300 (49.67%)
#  SHD: 101
# Completed iteration 150 of 300 (50.0%)
#  SHD: 90
# Completed iteration 151 of 300 (50.33%)
#  SHD: None
# Completed iteration 152 of 300 (50.67%)
#  SHD: None
# Completed iteration 153 of 300 (51.0%)
#  SHD: None
# Completed iteration 154 of 300 (51.33%)
#  SHD: 103
# Completed iteration 155 of 300 (51.67%)
#  SHD: 99
# Completed iteration 156 of 300 (52.0%)
#  SHD: 104
# Completed iteration 157 of 300 (52.33%)
#  SHD: 100
# Completed iteration 158 of 300 (52.67%)
#  SHD: 100
# Completed iteration 159 of 300 (53.0%)
#  SHD: 102
# Completed iteration 160 of 300 (53.33%)
#  SHD: 99
# Completed iteration 161 of 300 (53.67%)
#  SHD: 101
# Completed iteration 162 of 300 (54.0%)
#  SHD: 102
# Completed iteration 163 of 300 (54.33%)
#  SHD: 96
# Completed iteration 164 of 300 (54.67%)
#  SHD: 101
# Completed iteration 165 of 300 (55.0%)
#  SHD: 101
# Completed iteration 166 of 300 (55.33%)
#  SHD: 96
# Completed iteration 167 of 300 (55.67%)
#  SHD: 101
# Completed iteration 168 of 300 (56.0%)
#  SHD: 100
# Completed iteration 169 of 300 (56.33%)
#  SHD: 94
# Completed iteration 170 of 300 (56.67%)
#  SHD: 101
# Completed iteration 171 of 300 (57.0%)
#  SHD: 98
# Completed iteration 172 of 300 (57.33%)
#  SHD: 95
# Completed iteration 173 of 300 (57.67%)
#  SHD: 101
# Completed iteration 174 of 300 (58.0%)
#  SHD: 97
# Completed iteration 175 of 300 (58.33%)
#  SHD: 95
# Completed iteration 176 of 300 (58.67%)
#  SHD: 100
# Completed iteration 177 of 300 (59.0%)
#  SHD: 93
# Completed iteration 178 of 300 (59.33%)
#  SHD: 97
# Completed iteration 179 of 300 (59.67%)
#  SHD: 101
# Completed iteration 180 of 300 (60.0%)
#  SHD: 91
# Completed iteration 181 of 300 (60.33%)
#  SHD: None
# Completed iteration 182 of 300 (60.67%)
#  SHD: None
# Completed iteration 183 of 300 (61.0%)
#  SHD: None
# Completed iteration 184 of 300 (61.33%)
#  SHD: 105
# Completed iteration 185 of 300 (61.67%)
#  SHD: 99
# Completed iteration 186 of 300 (62.0%)
#  SHD: 104
# Completed iteration 187 of 300 (62.33%)
#  SHD: 103
# Completed iteration 188 of 300 (62.67%)
#  SHD: 99
# Completed iteration 189 of 300 (63.0%)
#  SHD: 102
# Completed iteration 190 of 300 (63.33%)
#  SHD: 99
# Completed iteration 191 of 300 (63.67%)
#  SHD: 100
# Completed iteration 192 of 300 (64.0%)
#  SHD: 102
# Completed iteration 193 of 300 (64.33%)
#  SHD: 98
# Completed iteration 194 of 300 (64.67%)
#  SHD: 100
# Completed iteration 195 of 300 (65.0%)
#  SHD: 102
# Completed iteration 196 of 300 (65.33%)
#  SHD: 96
# Completed iteration 197 of 300 (65.67%)
#  SHD: 100
# Completed iteration 198 of 300 (66.0%)
#  SHD: 101
# Completed iteration 199 of 300 (66.33%)
#  SHD: 96
# Completed iteration 200 of 300 (66.67%)
#  SHD: 100
# Completed iteration 201 of 300 (67.0%)
#  SHD: 99
# Completed iteration 202 of 300 (67.33%)
#  SHD: 96
# Completed iteration 203 of 300 (67.67%)
#  SHD: 100
# Completed iteration 204 of 300 (68.0%)
#  SHD: 97
# Completed iteration 205 of 300 (68.33%)
#  SHD: 95
# Completed iteration 206 of 300 (68.67%)
#  SHD: 100

# %%
results = results[results['directed']].sort_values(by='SHD')

# %%
results['root_nodes'] = results['dag'].apply(lambda x: x.root_nodes())
results['nroots'] = results['root_nodes'].apply(lambda x: len(x))
results['connected_roots'] = results['dag'].apply(lambda x: x.connected_roots())
results['nconroots'] = results['connected_roots'].apply(lambda x: len(x))

# %%
d = results.sort_values(by="shd_correct").iloc[0,:]['dag']
g = d.plot_structure()
igraph.plot(g)

# %%
[n for n in d.nodes if (len(d.parents(n)) == 0) & (len(d.children(n)) == 0)]
# Out:
# ['y_1', 'c_1', 'k_1', 'l_1', 'z_1', 'g_1', 'r_1', 'w_1', 'i_1']

# %%
g = gt.plot_structure()
igraph.plot(g)

# %%
x_0 = np.array([0.0 for i in range(len(data.columns))])
x_0[4] = 0.66
irf = d.calculate_irf(x_0)
plt = d.plot_irf(irf)
plt.show()

# %%
bl_children = np.where(np.isin(data.columns.values, shift.columns.values))[0]
bl_parents  = None # np.where(~np.isin(data.columns.values, shift.columns.values))[0]
d = data_array.shape[1]
# DAG
bnds = [
        (0, 0)
        if i == j
        else (0, 0) 
        if bl_parents is not None and i in bl_parents
        else (0, 0) 
        if bl_children is not None and j in bl_children
        else (-1 + tol, 1 - tol) # Assume stationary solution
        for i in range(d)
        for j in range(d)
    ]

# %%
W_est = linear.notears_linear(data_array, 
                              lambda1=1e-30, 
                              w_threshold=0.5,
                              loss_type='logistic', 
                              max_iter=10000, 
                              h_tol=1e-10, 
                              rho_max=1e+25, 
                              bnds=bnds)
adj_df = pd.DataFrame(W_est, index=data.columns.values, columns=data.columns.values)

# %%
d = dag(adj_df)

# %%
root_nodes = adj_df.columns.values[~adj_df.any()]
print(root_nodes)
print(np.count_nonzero(adj_df))
# Out:
# ['y_1' 'c_1' 'k_1' 'l_1' 'z_1' 'g_1' 'r_1' 'w_1' 'i_1']
# 27
